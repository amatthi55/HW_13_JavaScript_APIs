# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect

# %%
# Create engine using the `demographics.sqlite` database file
# YOUR CODE HERE
engine = create_engine("sqlite:///belly_button_biodiversity.sqlite")

# %%
# Declare a Base using `automap_base()`
# YOUR CODE HERE
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
# YOUR CODE HERE
Base.prepare(engine, reflect=True)

# %%
# Print all of the classes mapped to the Base
# YOUR CODE HERE
Base.classes.keys()
# Out:
# ['demographics']

# %%
# Assign the demographics class to a variable called `Demographics`
# YOUR CODE HERE
Demographics = Base.classes.demographics

# %%
# Create a session
# YOUR CODE HERE
session = Session(engine)

# %%
# Use the session to query Demographics table and display the first 5 locations
# YOUR CODE HERE
__first_row = session.query(Demographics.academic_degree, Demographics.occupation).all()
for element in __first_row:
    print(element)
# Out:
# ('PhD', 'Choreographer')
# ('Bachelor', 'Cellarman')
# ('Master', 'Veterinary Surgeon')
# ('PhD', 'Hawker')
# ('Bachelor', 'Choreographer')
# ('Bachelor', 'Medical Physicist')
# ('Master', 'Weaver')
# ('Master', 'Lighthouse Keeper')
# ('Master', 'Millwright')
# ('PhD', 'Medical Supplier')
# ('Bachelor', 'Manicurist')
# ('Bachelor', 'Window Dresser')
# ('Master', 'Assistant')
# ('Bachelor', 'Paramedic')
# ('Master', 'Genealogist')
# ('PhD', 'Servant')
# ('Bachelor', 'Technical Liaison')
# ('PhD', 'Scientist')
# ('PhD', 'Market Research')
# ('PhD', 'Medical Supplier')
# ('PhD', 'Actor')
# ('PhD', 'Claims Adjustor')
# ('Master', 'Groom')
# ('Master', 'Payroll Assistant')
# ('Bachelor', 'Machine Operator')
# ('Bachelor', 'Tea Blender')
# ('Bachelor', 'Warden')
# ('PhD', 'Undertaker')
# ('Master', 'Psychiatrist')
# ('Bachelor', 'Planning Technician')
# ('Bachelor', 'Booking Clerk')
# ('Bachelor', 'Track Worker')
# ('Bachelor', 'Sub-Postmaster')
# ('Master', 'Shelf Filler')
# ('Bachelor', 'Chemist')
# ('Bachelor', 'Injection Moulder')
# ('Bachelor', 'Stenographer')
# ('PhD', 'Betting Shop')
# ('Master', 'Hire Car Driver')
# ('Master', 'Heating Engineer')
# ('Master', 'Motor Mechanic')
# ('Bachelor', 'Vehicle Assessor')
# ('Bachelor', 'Tree Surgeon')
# ('PhD', 'Building Surveyor')
# ('PhD', 'Auto Electrician')
# ('Master', 'Park Ranger')
# ('Bachelor', 'Relocation Agent')
# ('Master', 'Advertising Contractor')
# ('Master', 'Furnace Man')
# ('PhD', 'Shooting Instructor')
# ('Bachelor', 'Travel Representative')
# ('Bachelor', 'Medical Physicist')
# ('PhD', 'Labourer')
# ('Master', 'Technical Analyst')
# ('Master', 'Actress')
# ('PhD', 'Show Jumper')
# ('PhD', 'Granite Technician')
# ('Bachelor', 'Share Dealer')
# ('Bachelor', 'Prison Officer')
# ('PhD', 'Riding Instructor')
# ('Bachelor', 'Rug Maker')
# ('Master', 'Marine Electrician')
# ('Bachelor', 'Stud Hand')
# ('Bachelor', 'Lighthouse Keeper')
# ('Master', 'Bus Conductor')
# ('Bachelor', 'Piano Tuner')
# ('Bachelor', 'Medical Researcher')
# ('PhD', 'Shipwright')
# ('Bachelor', 'Marketing Manager')
# ('Master', 'Insurance Inspector')
# ('PhD', 'Pallet Maker')
# ('Master', 'Road Safety Officer')
# ('PhD', 'School Crossing')
# ('Master', 'Opera Singer')
# ('PhD', 'Share Dealer')
# ('Master', 'Tour Agent')
# ('Bachelor', 'Pipe Inspector')
# ('Bachelor', 'Golf Club Professional')
# ('Master', 'Sportsperson')
# ('Bachelor', 'Maintenance Fitter')
# ('Bachelor', 'Seaman')
# ('PhD', 'Beauty Therapist')
# ('PhD', 'Stock Manager')
# ('Master', 'Theatre Technician')
# ('Master', 'Song Writer')
# ('PhD', 'Taxi Controller')
# ('Master', 'Lock Keeper')
# ('Bachelor', 'Grave Digger')
# ('Master', 'Sales Assistant')
# ('Master', 'Scaffolder')
# ('Bachelor', 'Systems Manager')
# ('PhD', 'Video Artist')
# ('Master', 'Art Restorer')
# ('Master', 'Herbalist')
# ('PhD', 'Zoologist')
# ('Bachelor', 'Housekeeper')
# ('Master', 'Planning Officer')
# ('Master', 'Car Valet')
# ('PhD', 'Bursar')
# ('PhD', 'Analyst')
# ('Bachelor', 'Zoologist')
# ('Bachelor', 'Doctor')
# ('Master', 'Public House Manager')
# ('PhD', 'Chiropractor')
# ('Master', 'Baggage Handler')
# ('Bachelor', 'Plant Operator')
# ('PhD', 'Station Manager')
# ('PhD', 'Metal Dealer')
# ('Master', 'Merchant')
# ('Master', 'Maintenance Fitter')
# ('Bachelor', 'Teachers Assistant')
# ('PhD', 'Mill Operator')
# ('Master', 'Riding Instructor')
# ('Master', 'Technical Director')
# ('Master', 'Maid')
# ('Master', 'Warehouseman')
# ('Bachelor', 'Lineman')
# ('Bachelor', 'Hypnotist')
# ('PhD', 'Transport Manager')
# ('Bachelor', 'Product Installer')
# ('Bachelor', 'Bank Messenger')
# ('Bachelor', 'Technical Director')
# ('Bachelor', 'Plant Manager')
# ('Master', 'Building Control')
# ('Bachelor', 'Green Keeper')
# ('PhD', 'Sales Executive')
# ('PhD', 'Nursing Sister')
# ('Bachelor', 'Child Minder')
# ('PhD', 'Horticultural Consultant')
# ('Master', 'Street Trader')
# ('Bachelor', 'Sports Coach')
# ('Master', 'Interior Decorator')
# ('Bachelor', 'Gate Keeper')
# ('Master', 'Nanny')
# ('PhD', 'Metallurgist')
# ('PhD', 'Shepherd')
# ('PhD', 'Analytical Chemist')
# ('PhD', 'Stud Hand')
# ('Bachelor', 'Technical Engineer')
# ('Bachelor', 'Circus Worker')
# ('PhD', 'Research Consultant')
# ('Master', 'Editor')
# ('Master', 'Steeplejack')
# ('Bachelor', 'Showman')
# ('Bachelor', 'Taxi Controller')
# ('Master', 'Hardware Dealer')
# ('Master', 'Decorator')
# ('PhD', 'Night Watchman')
# ('PhD', 'Stable Hand')
# ('Bachelor', 'Gaming Board Inspector')
# ('Master', 'Ticket Inspector')
# ('Bachelor', 'Technical Author')
# ('Master', 'Vehicle Engineer')
# ('PhD', 'Machine Minder')
# ('PhD', 'Parts Supervisor')
# ('Master', 'Greengrocer')
# ('Master', 'Chimney Sweep')
# ('Master', 'Geophysicist')
# ('PhD', 'Repair Man')
# ('Master', 'Purser')
# ('PhD', 'Lock Keeper')
# ('Master', 'Chimney Sweep')
# ('Bachelor', 'Payroll Clerk')
# ('Master', 'Tree Surgeon')
# ('Master', 'Machine Tool Fitter')
# ('PhD', 'Marquee Erector')
# ('Bachelor', 'Violin Maker')
# ('PhD', 'Script Writer')
# ('Bachelor', 'Tax Inspector')
# ('Bachelor', 'Nurseryman')
# ('PhD', 'Barrister')
# ('Bachelor', 'Precision Engineer')
# ('PhD', 'Gaming Club Manager')
# ('Bachelor', 'Shop Proprietor')
# ('Bachelor', 'Sales Director')
# ('Master', 'Textile Consultant')
# ('Bachelor', 'Plant Attendant')
# ('PhD', 'Rent Offcer')
# ('Bachelor', 'Typewriter Engineer')
# ('PhD', 'Quality Engineer')
# ('Master', 'Yacht Master')
# ('PhD', 'Operative')
# ('Bachelor', 'Technical Illustrator')
# ('Master', 'Sports Coach')
# ('PhD', 'Sales Assistant')
# ('PhD', 'Assistant Cook')
# ('PhD', 'Child Minder')
# ('Master', 'Breeder')
# ('PhD', 'Catering Staff')
# ('Bachelor', 'Pig Manager')
# ('PhD', 'Judge')
# ('Master', 'Acoustic Engineer')
# ('PhD', 'Clerk')
# ('Bachelor', 'Payroll Assistant')
# ('Bachelor', 'Travel Agent')
# ('Master', 'Clergyman')
# ('Master', 'Training Officer')
# ('Master', 'Research Scientist')
# ('Master', 'Car Park Attendant')
# ('PhD', 'Waiter')
# ('PhD', 'Sports Coach')
# ('PhD', 'Watchmaker')
# ('Master', 'Plant Driver')
# ('PhD', 'Palaeobotanist')
# ('Bachelor', 'Building Inspector')
# ('Bachelor', 'Proprietor')
# ('Master', 'Flour Miller')
# ('Master', 'Bingo Caller')
# ('PhD', 'Guest House Owner')
# ('Bachelor', 'Project Leader')
# ('Bachelor', 'Window Dresser')
# ('Master', 'Plant Engineer')
# ('Bachelor', 'Research Consultant')
# ('Bachelor', 'Tree Feller')
# ('PhD', 'Paint Consultant')
# ('Bachelor', 'Biologist')
# ('Master', 'Metallurgist')
# ('PhD', 'Laundry Staff')
# ('PhD', 'Tea Taster')
# ('Bachelor', 'Administrator')
# ('Master', 'Navigator')
# ('Master', 'Fraud Investigator')
# ('Bachelor', 'Press Operator')
# ('Bachelor', 'Station Manager')
# ('Master', 'Sales Support')
# ('PhD', 'Stationer')
# ('PhD', 'Shipping Officer')
# ('Bachelor', 'Plant Engineer')
# ('PhD', 'Delivery Driver')
# ('Bachelor', 'Golfer')
# ('PhD', 'Groom')
# ('PhD', 'Stock Controller')
# ('PhD', 'Pattern Weaver')
# ('Master', 'Optical')
# ('Bachelor', 'Special Constable')
# ('PhD', 'Caterer')
# ('Master', 'Baggage Handler')
# ('Master', 'Brewery Manager')
# ('PhD', 'Careers Officer')
# ('PhD', 'Transport Engineer')
# ('Master', 'Road Sweeper')
# ('Bachelor', 'Physiologist')
# ('Master', 'Graphologist')
# ('Bachelor', 'Recruitment Consultant')
# ('PhD', 'Forwarding Agent')
# ('Bachelor', 'Production Engineer')
# ('Bachelor', 'Tea Blender')
# ('PhD', 'Ticket Inspector')
# ('PhD', 'Fund Raiser')
# ('PhD', 'Highway Inspector')
# ('Master', 'Loss Assessor')
# ('Bachelor', 'Turf Accountant')
# ('PhD', 'Project Manager')
# ('PhD', 'Textile Technician')
# ('Master', 'Garage Foreman')
# ('PhD', 'Church Officer')
# ('Master', 'Meteorologist')
# ('Master', 'Sound Engineer')
# ('Master', 'Locum Pharmacist')
# ('Bachelor', 'Pipe Inspector')
# ('PhD', 'Garage Manager')
# ('Bachelor', 'Masseur')
# ('Bachelor', 'Screen Printer')
# ('PhD', 'Saw Miller')
# ('Bachelor', 'Typesetter')
# ('Bachelor', 'Service Manager')
# ('PhD', 'Carpenter')
# ('PhD', 'Ticket Inspector')
# ('Master', 'Radio Presenter')
# ('Bachelor', 'Plumber')
# ('Bachelor', 'Furniture Remover')
# ('PhD', 'Stock Manager')
# ('Bachelor', 'Stage Director')
# ('Master', 'Park Keeper')
# ('Bachelor', 'Marketing Assistant')
# ('Master', 'Picture Editor')
# ('Master', 'Shop Keeper')
# ('PhD', 'Project Leader')
# ('PhD', 'Sheet Metal Worker')
# ('PhD', 'Philatelist')
# ('PhD', 'Historian')
# ('Master', 'Ship Builder')
# ('PhD', 'Toy Maker')
# ('Bachelor', 'Shooting Instructor')
# ('Master', 'Production Engineer')
# ('Master', 'Property Manager')
# ('PhD', 'Panel Beater')
# ('Master', 'IT Manager')
# ('PhD', 'Meat Inspector')
# ('Bachelor', 'Technical Director')
# ('Bachelor', 'Site Engineer')
# ('Master', 'Vehicle Assessor')
# ('Master', 'Horticulturalist')
# ('Master', 'Lorry Driver')
# ('Bachelor', 'Watchmaker')
# ('PhD', 'Tailor')
# ('Master', 'Foreman')
# ('PhD', 'Foster Parent')
# ('Bachelor', 'Body Fitter')
# ('Master', 'Licensing')
# ('PhD', 'Insurance Consultant')
# ('Bachelor', 'Tunneller')
# ('PhD', 'Horse Breeder')
# ('Bachelor', 'Car Salesman')
# ('Master', 'Arts')
# ('PhD', 'Manicurist')
# ('Master', 'Handyman')
# ('Master', 'Geologist')
# ('Master', 'Fuel Merchant')
# ('Master', 'Flour Miller')
# ('PhD', 'Racehorse Groom')
# ('Bachelor', 'Palaeobotanist')
# ('Master', 'Orthoptist')
# ('Bachelor', 'Machine Tool Fitter')
# ('Master', 'Stud Hand')
# ('PhD', 'Medical Physicist')
# ('PhD', 'Bill Poster')
# ('Master', 'Theatre Manager')
# ('Bachelor', 'Envoy')
# ('Bachelor', 'Progress Chaser')
# ('Bachelor', 'Bank Manager')
# ('Bachelor', 'Stable Hand')
# ('Master', 'Health Planner')
# ('PhD', 'Technical Clerk')
# ('Master', 'Cleric')
# ('PhD', 'Armourer')
# ('PhD', 'Lighthouse Keeper')
# ('Bachelor', 'Purser')
# ('Bachelor', 'Industrial Chemist')
# ('Master', 'Jazz Composer')
# ('PhD', 'Brewery Worker')
# ('PhD', 'Tacker')
# ('PhD', 'Plastics Engineer')
# ('PhD', 'Medical Physicist')
# ('Bachelor', 'Off Shore')
# ('Master', 'Technical Assistant')
# ('Master', 'Microbiologist')
# ('Bachelor', 'Plumber')
# ('Master', 'Polisher')
# ('PhD', 'Metal Polisher')
# ('Bachelor', 'Machine Operator')
# ('Bachelor', 'Lithographer')
# ('Bachelor', 'Gaming Club Proprietor')
# ('PhD', 'TV Editor')
# ('Bachelor', 'Bookmaker')
# ('Bachelor', 'Sales Support')
# ('Bachelor', 'Navigator')
# ('Master', 'Motor Engineer')
# ('Master', 'Store Detective')
# ('PhD', 'Stage Manager')
# ('PhD', 'Nurseryman')
# ('PhD', 'Security Guard')
# ('Master', 'Gardener')
# ('Master', 'Locum Pharmacist')
# ('Master', 'Aerial Erector')
# ('Master', 'Stockman')
# ('PhD', 'Engineer')
# ('Bachelor', 'Tacker')
# ('Master', 'Waitress')
# ('PhD', 'Car Valet')
# ('Bachelor', 'Councillor')
# ('Bachelor', 'Graphic Designer')
# ('PhD', 'Jockey')
# ('Bachelor', 'Sports Administrator')
# ('PhD', 'Steeplejack')
# ('PhD', 'Lawyer')
# ('Bachelor', 'Valve Technician')
# ('Bachelor', 'Hotel Consultant')
# ('Master', 'Publishing Manager')
# ('Bachelor', 'Porter')
# ('Bachelor', 'Liaison Officer')
# ('PhD', 'Script Writer')
# ('Master', 'Guest House Proprietor')
# ('PhD', 'Assistant')
# ('Bachelor', 'Joinery Consultant')
# ('Bachelor', 'Barman')
# ('Bachelor', 'Bodyshop')
# ('PhD', 'Pasteuriser')
# ('Bachelor', 'Training Officer')
# ('PhD', 'Hosiery Worker')
# ('PhD', 'Quality Engineer')
# ('Bachelor', 'Publican')
# ('Master', 'Geophysicist')
# ('Bachelor', 'Treasurer')
# ('Master', 'Camera Repairer')
# ('Master', 'Merchant')
# ('Bachelor', 'Wood Cutter')
# ('Bachelor', 'Aircraft Surface Finisher')
# ('PhD', 'Magistrate')
# ('Master', 'Mortgage Broker')
# ('PhD', 'Procurator Fiscal')
# ('Bachelor', 'Patent Agent')
# ('Bachelor', 'Glazier')
# ('Master', 'Sales Support')
# ('Master', 'Map Mounter')
# ('PhD', 'Technical Analyst')
# ('Bachelor', 'Homecare Manager')
# ('PhD', 'Booking Clerk')
# ('Bachelor', 'Barman')
# ('Bachelor', 'Gravel Merchant')
# ('PhD', 'Tax Inspector')
# ('Bachelor', 'Aerobic Instructor')
# ('PhD', 'Textile Engineer')
# ('PhD', 'Chartered')
# ('Master', 'Press Operator')
# ('PhD', 'Maid')
# ('Bachelor', 'Assessor')
# ('PhD', 'Advertising Contractor')
# ('PhD', 'Piano Tuner')
# ('PhD', 'Laminator')
# ('PhD', 'Mining Consultant')
# ('PhD', 'Judge')
# ('Master', 'Cafe Owner')
# ('Master', 'Valuer')
# ('PhD', 'Calibration Manager')
# ('PhD', 'Plant Manager')
# ('Master', 'Meter Reader')
# ('PhD', 'IT Consultant')
# ('Bachelor', 'Butler')
# ('PhD', 'Groundsman')
# ('Master', 'Orthoptist')
# ('Master', 'Ice Cream Vendor')
# ('Bachelor', 'Area Manager')
# ('Bachelor', 'Radio Controller')
# ('Bachelor', 'Wood Worker')
# ('Master', 'Merchant Banker')
# ('Master', 'Mill Operator')
# ('PhD', 'Marble Mason')
# ('Master', 'Gambler')
# ('Master', 'Physicist')
# ('Master', 'Gamekeeper')
# ('Bachelor', 'Panel Beater')
# ('PhD', 'Technical Director')
# ('Bachelor', 'Professional Wrestler')
# ('Bachelor', 'Warehouse Manager')
# ('Master', 'Bus Company')
# ('PhD', 'Groundsman')
# ('PhD', 'Tank Farm Operative')
# ('Bachelor', 'Vehicle Technician')
# ('Bachelor', 'Cargo Operator')
# ('PhD', 'Balloonist')
# ('Bachelor', 'Civil Servant')
# ('PhD', 'Wine Merchant')
# ('Bachelor', 'Telex Operator')
# ('Bachelor', 'Carpenter')
# ('Master', 'Training Officer')
# ('Master', 'Special Needs')
# ('Master', 'Applications Engineer')
# ('Bachelor', 'Trade Union Official')
# ('Master', 'Literary Agent')
# ('PhD', 'Art Restorer')
# ('Bachelor', 'Landworker')
# ('PhD', 'Chiropractor')
# ('PhD', 'Medical Advisor')
# ('PhD', 'Radiologist')
# ('PhD', 'Horse Trader')
# ('Master', 'Furniture Restorer')
# ('PhD', 'Gas Mechanic')
# ('Bachelor', 'Screen Printer')
# ('Bachelor', 'Welfare Rights Officer')
# ('Master', 'Blind Assembler')
# ('PhD', 'Yard Manager')
# ('Master', 'Signwriter')
# ('Bachelor', 'Nuclear Scientist')
# ('PhD', 'Telecommunications')
# ('PhD', 'Project Engineer')
# ('Bachelor', 'Seaman')
# ('Master', 'Medical Assistant')
# ('PhD', 'Labelling Operator')
# ('PhD', 'Highway Inspector')
# ('PhD', 'Potter')
# ('Master', 'Nun')
# ('Master', 'Gambler')
# ('Bachelor', 'Furnace Man')
# ('Master', 'Reflexologist')
# ('Master', 'Public House Manager')
# ('PhD', 'Resin Caster')
# ('Master', 'Technical Advisor')
# ('PhD', 'Stage Hand')
# ('Master', 'Lawyer')
# ('PhD', 'Violinist')
# ('Bachelor', 'Barman')
# ('Bachelor', 'Food Processor')
# ('PhD', 'Funeral Furnisher')
# ('Master', 'Producer')
# ('Master', 'Biochemist')
# ('PhD', 'Catering Manager')
# ('PhD', 'Lift Attendant')
# ('PhD', 'Scientist')
# ('Bachelor', 'Choreographer')
# ('PhD', 'Furniture Dealer')
# ('Master', 'Hearing Therapist')
# ('PhD', 'Royal Marine')
# ('PhD', 'Flying Instructor')
# ('Master', 'Marine Consultant')
# ('PhD', 'Motor Fitter')
# ('PhD', 'Trainee Manager')
# ('Bachelor', 'Blinds Installer')
# ('PhD', 'Bus Valeter')
# ('Master', 'School Crossing')
# ('PhD', 'Airport Manager')
# ('PhD', 'Repairer')
# ('PhD', 'Screen Writer')
# ('Master', 'Grocer')
# ('Master', 'Typewriter Engineer')
# ('Master', 'Building Estimator')
# ('Bachelor', 'Make Up Artist')
# ('PhD', 'Outdoor Pursuits')
# ('Bachelor', 'Aerial Erector')
# ('Bachelor', 'Maths Teacher')
# ('Bachelor', 'English Teacher')
# ('PhD', 'Medical Assistant')
# ('PhD', 'Television Producer')
# ('Bachelor', 'Economist')
# ('Master', 'Baptist Minister')
# ('PhD', 'Weighbridge Operator')
# ('Master', 'Patent Agent')
# ('Bachelor', 'Biologist')
# ('Master', 'Bus Company')
# ('Master', 'Weighbridge Operator')
# ('Master', 'Magistrate')
# ('Bachelor', 'Violin Maker')
# ('Master', 'Van Driver')
# ('PhD', 'Publican')
# ('Bachelor', 'Technical Engineer')
# ('Master', 'Training Consultant')
# ('PhD', 'Charge Hand')
# ('Master', 'Brewery Worker')
# ('Master', 'Pest Controller')
# ('Bachelor', 'Clergyman')
# ('PhD', 'Floor Layer')
# ('Master', 'Steward')
# ('Bachelor', 'Auxiliary Nurse')
# ('PhD', 'Remedial Therapist')
# ('Master', 'Assembly Worker')
# ('Bachelor', 'Steeplejack')
# ('Bachelor', 'Fuel Merchant')
# ('Bachelor', 'Maths Teacher')
# ('Bachelor', 'Foundry Worker')
# ('PhD', 'Home Economist')
# ('PhD', 'Quality Technician')
# ('Master', 'Minicab Driver')
# ('Master', 'Nurseryman')
# ('Master', 'Minibus Driver')
# ('PhD', 'Marine Geologist')
# ('Master', 'Probation Worker')
# ('Master', 'Patrolman')
# ('Master', 'Artexer')
# ('Bachelor', 'Lithographer')
# ('Bachelor', 'Bodyguard')
# ('PhD', 'Lorry Driver')
# ('PhD', 'Art Dealer')
# ('Master', 'Immigration Officer')
# ('Bachelor', 'Bodyshop')
# ('Bachelor', 'Investment Banker')
# ('Bachelor', 'Bookmaker')
# ('Master', 'Travel Agent')
# ('Master', 'China Restorer')
# ('PhD', 'Shipyard Worker')
# ('Bachelor', 'Printer')
# ('Bachelor', 'Fork Lift Truck Driver')
# ('Bachelor', 'Assistant Caretaker')
# ('Master', 'Circus Proprietor')
# ('Bachelor', 'Pastry Chef')
# ('Master', 'Pipe Insulator')
# ('Master', 'Postwoman')
# ('Bachelor', 'Saw Miller')
# ('Bachelor', 'Public House Manager')
# ('Bachelor', 'Licensing')
# ('Master', 'Analyst')
# ('Bachelor', 'Public House Manager')
# ('PhD', 'Tax Consultant')
# ('Bachelor', 'Ship Broker')
# ('PhD', 'Welfare Assistant')
# ('Bachelor', 'Charity Worker')
# ('Master', 'Blinds Installer')
# ('Bachelor', 'Tanner')
# ('Master', 'Car Valet')
# ('Bachelor', 'Medical Practitioner')
# ('Master', 'IT Trainer')
# ('PhD', 'Merchant Banker')
# ('PhD', 'Carpenter')
# ('PhD', 'Lighterman')
# ('PhD', 'Tutor')
# ('Master', 'Camera Repairer')
# ('Bachelor', 'Golf Club Professional')
# ('Bachelor', 'Instructor')
# ('PhD', 'Investment Manager')
# ('Bachelor', 'Building Inspector')
# ('Master', 'Training Consultant')
# ('Bachelor', 'Saw Miller')
# ('Bachelor', 'Chimney Sweep')
# ('Master', 'Roofer')
# ('Bachelor', 'Auctioneer')
# ('Bachelor', 'Research Scientist')
# ('PhD', 'Barrister')
# ('Master', 'Planning Officer')
# ('Bachelor', 'Chemist')
# ('PhD', 'Merchant Seaman')
# ('Master', 'Laminator')
# ('Bachelor', 'Trade Mark Agent')
# ('PhD', 'Transport Engineer')
# ('Bachelor', 'Marine Geologist')
# ('Master', 'Midwife')
# ('Bachelor', 'Arts')
# ('Master', 'Watchmaker')
# ('Master', 'Catering Consultant')
# ('PhD', 'Legal Executive')
# ('Bachelor', 'Toy Trader')
# ('Bachelor', 'Advertising Assistant')
# ('Master', 'Milklady')
# ('Master', 'Stone Cutter')
# ('PhD', 'Administrator')
# ('PhD', 'Off Shore')
# ('Master', 'Payroll Manager')
# ('Bachelor', 'Immigration Officer')
# ('PhD', 'Restaurateur')
# ('Master', 'Telephonist')
# ('PhD', 'Astronomer')
# ('PhD', 'Turkey Farmer')
# ('Bachelor', 'Oil Broker')
# ('PhD', 'Mathematician')
# ('Bachelor', 'Cashier')
# ('Master', 'Piano Tuner')
# ('PhD', 'Blind Assembler')
# ('PhD', 'Quality Inspector')
# ('Master', 'Investigator')
# ('PhD', 'Park Ranger')
# ('Master', 'Hospital Orderly')
# ('Master', 'Hardware Dealer')
# ('Master', 'Restaurant Manager')
# ('Bachelor', 'Psychiatrist')
# ('PhD', 'Actuary')
# ('Bachelor', 'Fraud Investigator')
# ('Master', 'Bank Messenger')
# ('Master', 'Planning Officer')
# ('Bachelor', 'Immigration Officer')
# ('PhD', 'Laminator')
# ('Master', 'Auctioneer')
# ('PhD', 'Barmaid')
# ('Master', 'Editor')
# ('Bachelor', 'Groom')
# ('Master', 'Training Instructor')
# ('Master', 'English Teacher')
# ('Master', 'Inventor')
# ('Bachelor', 'Nurseryman')
# ('Master', 'Tattooist')
# ('Bachelor', 'Technical Manager')
# ('Master', 'Chiropodist')
# ('Bachelor', 'Stock Controller')
# ('PhD', 'Produce Supervisor')
# ('Bachelor', 'Advertising Contractor')
# ('PhD', 'Merchant')
# ('Master', 'Research Consultant')
# ('PhD', 'Scientific Officer')
# ('Bachelor', 'Hawker')
# ('Bachelor', 'Shooting Instructor')
# ('Master', 'Fuel Merchant')
# ('Master', 'Broadcaster')
# ('PhD', 'Library Manager')
# ('Master', 'Charge Hand')
# ('Bachelor', 'Radio Controller')
# ('Master', 'Street Entertainer')
# ('Master', 'Piano Teacher')
# ('Bachelor', 'Resin Caster')
# ('Master', 'Cartographer')
# ('Bachelor', 'Ambulance Controller')
# ('PhD', 'Catering Manager')
# ('Master', 'Spring Maker')
# ('PhD', 'Picture Editor')
# ('Bachelor', 'Delivery Driver')
# ('PhD', 'Voluntary Worker')
# ('PhD', 'Gardener')
# ('Master', 'Floor Layer')
# ('Bachelor', 'Planning Technician')
# ('Master', 'Flying Instructor')
# ('Bachelor', 'Television Engineer')
# ('PhD', 'Tax Inspector')
# ('Master', 'Cinema Manager')
# ('Master', 'Marine Electrician')
# ('Bachelor', 'Furniture Remover')
# ('PhD', 'Office Manager')
# ('Bachelor', 'Lawn Mower')
# ('PhD', 'Furnace Man')
# ('Master', 'Economist')
# ('PhD', 'Sales Representative')
# ('Bachelor', 'Transport Clerk')
# ('Master', 'Inventor')
# ('Bachelor', 'Nurseryman')
# ('Bachelor', 'Yard Manager')
# ('PhD', 'Music Teacher')
# ('PhD', 'Palaeobotanist')
# ('Bachelor', 'Sign Maker')
# ('PhD', 'Insurance Consultant')
# ('Bachelor', 'IT Trainer')
# ('Master', 'Window Cleaner')
# ('Master', 'Physiotherapist')
# ('PhD', 'Bill Poster')
# ('PhD', 'Butchery Manager')
# ('PhD', 'Building Surveyor')
# ('Bachelor', 'Postman')
# ('PhD', 'Leaflet Distributor')
# ('Bachelor', 'Advertising Clerk')
# ('Bachelor', 'Maintenance Fitter')
# ('PhD', 'Masseuse')
# ('PhD', 'Tractor Driver')
# ('PhD', 'Patent Attorney')
# ('Bachelor', 'Tunneller')
# ('Bachelor', 'Script Writer')
# ('PhD', 'Business Proprietor')
# ('Bachelor', 'Carphone Fitter')
# ('Master', 'Lighthouse Keeper')
# ('Bachelor', 'Park Ranger')
# ('PhD', 'Broadcaster')
# ('Master', 'Claims Adjustor')
# ('Master', 'Quality Inspector')
# ('PhD', 'Recovery Vehicle Coordinator')
# ('Bachelor', 'Psychiatrist')
# ('PhD', 'Adjustor')
# ('PhD', 'Laboratory Analyst')
# ('Bachelor', 'Gate Keeper')
# ('Bachelor', 'Doctor')
# ('Bachelor', 'Warden')
# ('Master', 'Teacher')
# ('PhD', 'Motor Fitter')
# ('PhD', 'Photographer')
# ('Master', 'Professional Racing')
# ('Master', 'Shipwright')
# ('Master', 'Stenographer')
# ('PhD', 'Hospital Consultant')
# ('Bachelor', 'Tyre Technician')
# ('Bachelor', 'Cable Contractor')
# ('PhD', 'Retired')
# ('Master', 'Underwriter')
# ('Bachelor', 'Newsagent')
# ('Bachelor', 'Textile Engineer')
# ('PhD', 'Highway Inspector')
# ('PhD', 'Goldsmith')
# ('Bachelor', 'Literary Agent')
# ('Master', 'Trainee Manager')
# ('Bachelor', 'Payroll Assistant')
# ('PhD', 'Ventriloquist')
# ('PhD', 'Cafe Worker')
# ('Master', 'Revenue Officer')
# ('Bachelor', 'Textile Consultant')
# ('Bachelor', 'Mining Engineer')
# ('PhD', 'Entertainer')
# ('PhD', 'Tax Analyst')
# ('Bachelor', 'Roofer')
# ('PhD', 'Furrier')
# ('Master', 'Hire Car Driver')
# ('PhD', 'Ambulance Driver')
# ('Master', 'Student Nurse')
# ('PhD', 'Housekeeper')
# ('PhD', 'Sports Administrator')
# ('Bachelor', 'Airport Controller')
# ('PhD', 'Graphic Designer')
# ('PhD', 'Audit Manager')
# ('PhD', 'Fruiterer')
# ('PhD', 'Shelter Warden')
# ('Bachelor', 'Service Engineer')
# ('Master', 'Chef')
# ('PhD', 'Mortician')
# ('PhD', 'Administration Staff')
# ('PhD', 'Jockey')
# ('Master', 'Marketing Coordinator')
# ('Bachelor', 'Rent Offcer')
# ('PhD', 'Property Buyer')
# ('PhD', 'Playgroup Leader')
# ('Master', 'Line Manager')
# ('PhD', 'Warehouseman')
# ('Bachelor', 'Catering Manager')
# ('Bachelor', 'Medical Assistant')
# ('PhD', 'Research Consultant')
# ('PhD', 'Hosiery Worker')
# ('Bachelor', 'Motor Racing')
# ('PhD', 'Literary Agent')
# ('Bachelor', 'Accountant')
# ('Master', 'Regulator')
# ('PhD', 'Caterer')
# ('Master', 'Pools Collector')
# ('Master', 'Acupuncturist')
# ('Master', 'Textile Worker')
# ('PhD', 'Tyre Fitter')
# ('Bachelor', 'Tax Manager')
# ('Master', 'Art Critic')
# ('Master', 'Line Manager')
# ('Bachelor', 'Medical Consultant')
# ('PhD', 'Cable Jointer')
# ('Bachelor', 'Merchant Seaman')
# ('Master', 'Magician')
# ('Bachelor', 'Print Finisher')
# ('PhD', 'Technical Illustrator')
# ('PhD', 'Property Developer')
# ('Bachelor', 'Technical Director')
# ('Bachelor', 'Foster Parent')
# ('Master', 'Textile Technician')
# ('PhD', 'Fireman')
# ('Master', 'Labourer')
# ('Master', 'Waiter')
# ('Bachelor', 'Progress Clerk')
# ('Master', 'Professional Wrestler')
# ('Bachelor', 'Lighting Technician')
# ('Bachelor', 'Insurance Broker')
# ('Bachelor', 'Television Producer')
# ('Master', 'Oil Broker')
# ('Master', 'Laundry Staff')
# ('Master', 'Pipe Fitter')
# ('Bachelor', 'Playgroup Assistant')
# ('PhD', 'Interpreter')
# ('PhD', 'Payroll Manager')
# ('PhD', 'Quality Engineer')
# ('Master', 'Planning Manager')
# ('Bachelor', 'Plater')
# ('Master', 'Regulator')
# ('Master', 'Training Manager')
# ('PhD', 'Lock Keeper')
# ('Bachelor', 'Labourer')
# ('Bachelor', 'Blind Fitter')
# ('PhD', 'Medical Advisor')
# ('Bachelor', 'Lime Kiln Attendant')
# ('Bachelor', 'Hop Merchant')
# ('PhD', 'Stone Sawyer')
# ('PhD', 'Hospital Orderly')
# ('PhD', 'Transport Controller')
# ('Bachelor', 'Lighterman')
# ('Bachelor', 'Optical Advisor')
# ('Master', 'Museum Assistant')
# ('Bachelor', 'Office Worker')
# ('Master', 'Wages Clerk')
# ('Bachelor', 'Marine Pilot')
# ('PhD', 'Scientist')
# ('Master', 'Metal Worker')
# ('Bachelor', 'Housewife')
# ('PhD', 'Metallurgist')
# ('Bachelor', 'Turner')
# ('PhD', 'Shooting Instructor')
# ('Master', 'Law Clerk')
# ('PhD', 'Stewardess')
# ('Master', 'Bodyguard')
# ('Master', 'Marine Surveyor')
# ('Master', 'Radio Controller')
# ('PhD', 'Chambermaid')
# ('PhD', 'Hardware Dealer')
# ('Master', 'Marketing Assistant')
# ('Bachelor', 'Lawyer')
# ('PhD', 'Mill Operator')
# ('PhD', 'Surveyor')
# ('Bachelor', 'Television Producer')
# ('Bachelor', 'Botanist')
# ('Master', 'Forensic Scientist')
# ('Master', 'Pools Collector')
# ('Master', 'Furrier')
# ('PhD', 'Vehicle Body Worker')
# ('PhD', 'Pawnbroker')
# ('Bachelor', 'Health And Safety')
# ('Master', 'Van Driver')
# ('Bachelor', 'Hypnotist')
# ('PhD', 'Broadcaster')
# ('PhD', 'Telephonist')
# ('Bachelor', 'Pattern Cutter')
# ('Bachelor', 'Hospital Worker')
# ('PhD', 'Radiologist')
# ('Master', 'Barrister')
# ('Bachelor', 'Technical Editor')
# ('Master', 'Sales Engineer')
# ('Master', 'Bus Mechanic')
# ('PhD', 'Chiropodist')
# ('PhD', 'Marine Engineer')
# ('PhD', 'Civil Servant')
# ('Bachelor', 'Circus Proprietor')
# ('PhD', 'Handyman')
# ('Master', 'Payroll Clerk')
# ('PhD', 'Pawnbroker')
# ('Master', 'Marketing Director')
# ('Master', 'Assistant Teacher')
# ('Bachelor', 'Oil Rig Crew')
# ('PhD', 'Mill Operator')
# ('Bachelor', 'Chandler')
# ('Bachelor', 'Marine Pilot')
# ('PhD', 'Lawn Mower')
# ('PhD', 'Technical Advisor')
# ('Bachelor', 'Quality Inspector')
# ('Bachelor', 'Sales Manager')
# ('Bachelor', 'Quality Technician')
# ('Master', 'Graphic Designer')
# ('Master', 'Reflexologist')
# ('Bachelor', 'Goods Handler')
# ('Master', 'Wages Clerk')
# ('Bachelor', 'Fuel Merchant')
# ('PhD', 'Insurance Broker')
# ('PhD', 'Pawnbroker')
# ('Bachelor', 'Portfolio Manager')
# ('Master', 'Homecare Manager')
# ('PhD', 'Interviewer')
# ('Bachelor', 'Blinds Installer')
# ('PhD', 'Plater')
# ('PhD', 'Knitter')
# ('Master', 'Waiter')
# ('Bachelor', 'Travel Clerk')
# ('Bachelor', 'Metal Polisher')
# ('PhD', 'Metal Polisher')
# ('Bachelor', 'Radio Operator')
# ('PhD', 'Taxi Controller')
# ('PhD', 'Writer')
# ('Master', 'Pig Manager')
# ('Master', 'Preacher')
# ('PhD', 'Brewery Manager')
# ('Master', 'Welfare Rights Officer')
# ('Bachelor', 'Gaming Club Proprietor')
# ('Master', 'Lighterman')
# ('Master', 'Physicist')
# ('PhD', 'Valve Technician')
# ('Bachelor', 'Transport Controller')
# ('Master', 'Handyman')
# ('Master', 'Hygienist')
# ('Master', 'Rose Grower')
# ('Bachelor', 'Microbiologist')
# ('PhD', 'Medical Supplier')
# ('Bachelor', 'Probation Worker')
# ('Bachelor', 'Psychoanalyst')
# ('Bachelor', 'Lift Attendant')
# ('PhD', 'Letting Agent')
# ('PhD', 'Technical Clerk')
# ('Bachelor', 'Retired')
# ('PhD', 'Typewriter Engineer')
# ('PhD', 'Map Mounter')
# ('PhD', 'Radio Producer')
# ('Master', 'Motor Racing')
# ('Bachelor', 'Traffic Warden')
# ('Bachelor', 'Temperature Time')
# ('Master', 'Gambler')
# ('Master', 'Investment Manager')
# ('PhD', 'Health Visitor')
# ('Bachelor', 'Production Manager')
# ('Master', 'Health Advisor')
# ('Bachelor', 'Graphologist')
# ('Master', 'Orthopaedic')
# ('Bachelor', 'Ironmonger')
# ('PhD', 'Administration Assistant')
# ('Master', 'Sports Coach')
# ('Master', 'Violinist')
# ('Bachelor', 'Post Sorter')
# ('Master', 'Off Shore')
# ('PhD', 'Motor Engineer')
# ('Bachelor', 'Attendant')
# ('PhD', 'Security Guard')
# ('Master', 'Military Leader')
# ('Bachelor', 'Booking Agent')
# ('Master', 'Museum Attendant')
# ('PhD', 'French Polisher')
# ('PhD', 'Hotel Consultant')
# ('Bachelor', 'Entertainer')
# ('Master', 'Sales Assistant')
# ('Bachelor', 'Land Agent')
# ('Master', 'Orthopaedic')
# ('Master', 'Pig Man')
# ('Master', 'Instrument Supervisor')
# ('Master', 'Gamekeeper')
# ('Master', 'Stenographer')
# ('PhD', 'Park Keeper')
# ('Bachelor', 'Press Officer')
# ('Bachelor', 'Turkey Farmer')
# ('PhD', 'Paramedic')
# ('Master', 'Property Manager')
# ('Bachelor', 'Psychologist')
# ('PhD', 'Tax Consultant')
# ('Master', 'Transport Controller')
# ('Bachelor', 'Furnace Man')
# ('Master', 'Actuary')
# ('Bachelor', 'Stone Sawyer')
# ('PhD', 'Applications Engineer')
# ('Master', 'Instructor')
# ('Master', 'Engineer')
# ('PhD', 'Word Processing Operator')
# ('Bachelor', 'Metal Polisher')
# ('PhD', 'Plant Attendant')
# ('Bachelor', 'Betting Shop')
# ('PhD', 'Slater')
# ('Bachelor', 'Tunneller')
# ('Bachelor', 'Storeman')
# ('Bachelor', 'Stud Hand')
# ('Master', 'Production Planner')
# ('Master', 'Sports Administrator')
# ('Bachelor', 'Steel Erector')
# ('Bachelor', 'Tiler')
# ('PhD', 'Wholesale Newspaper')
# ('Bachelor', 'Safety Officer')
# ('Master', 'Building Estimator')
# ('PhD', 'Plastics Consultant')
# ('Bachelor', 'Tea Taster')
# ('Master', 'Hospital Doctor')
# ('Master', 'Purchasing Assistant')
# ('PhD', 'Garage Manager')
# ('Master', 'Trichologist')
# ('Master', 'Partition Erector')
# ('Bachelor', 'Playgroup Leader')
# ('Bachelor', 'Nursery Nurse')
# ('Master', 'Word Processing Operator')
# ('PhD', 'Shepherd')

# %%
# BONUS: Query and print the number of unique Locations
# Hints: Look into counting and grouping operations in SQLAlchemy
# YOUR CODE HERE
